# %%
from numpy import array
from math import sqrt

import matplotlib.pyplot as plt
# %matplotlib inline

from pyspark.mllib.clustering import KMeans, KMeansModel

# %% [markdown]
# F

# %%
data = sc.textFile("a3.txt")
parsedData = data.map(lambda line: array([float(x) for x in line.strip().split()]))
parsedData.take(5)
# Out:
# [array([53920., 42968.]),
#  array([52019., 42206.]),
#  array([52570., 42476.]),
#  array([54220., 42081.]),
#  array([54268., 43420.])]

# %%
clusters = KMeans.train(parsedData, 50, maxIterations=150, initializationMode="random")

# %%
x, y = list(zip(*clusters.centers))
xd, yd = zip(*parsedData.collect())

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(xd,yd, s=1, c='r', marker="o", label='second')
ax1.scatter(x, y, s=5, c='b', marker="s", label='first')
