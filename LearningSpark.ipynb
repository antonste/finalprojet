# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
lines = sc.textFile("a3.txt")
lineLengths = lines.map(lambda s: len(s))
totalLength = lineLengths.reduce(lambda a, b: a + b)

# %%
def clean_line(line):
    x, y = line.strip().split()
    return int(x), int(y)

linesrdd = lines.map(clean_line)
linesrdd.toDF(('x','y'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-9b110a8c331f> in <module>
#       4
#       5 linesrdd = lines.map(clean_line)
# ----> 6 linesrdd.show()
#
# AttributeError: 'PipelinedRDD' object has no attribute 'show'

# %%
linesdf = linesrdd.toDF(('x','y'))
linesdf.describe().show()
# Out:
# +-------+------------------+-----------------+
# |summary|                 x|                y|
# +-------+------------------+-----------------+
# |  count|              7500|             7500|
# |   mean|32561.752666666667|34150.54026666666|
# | stddev| 17733.44519915902|17699.37539368051|
# |    min|                 0|              976|
# |    max|             65535|            64142|
# +-------+------------------+-----------------+

# %%
linesdf.toPandas().plot.scatter(x="x", y="y")
plt.show()

# %%
# Out:
# UsageError: Line magic function `%lprun` not found.
